# %% [markdown]
# # Practica 7 - Distribucion de Probabilidad Discretas
#
# ##### Nombre: Juan Francisco Pelaez Becerra
#
# ##### Fecha: 30/07/2022

# %%
#Librerias
import matplotlib.pyplot as plt
import numpy as np 
from scipy import stats 
import seaborn as sns

# %% [markdown]
# ######  Se determina distribucion de probabilidad discreta cuando representan un número entero y finito de posibles valores, como el número de individuos en un grupo de personas.

# %% [markdown]
#
#
# *   **Distribución de Hipergeométrica :** La distribución hipergeométrica es especialmente útil en todos aquellos casos en los que se extraigan muestras o se realizan experiencias repetidas sin devolución del elemento extraído o sin retornar a la situación experimental inicial.
#
#   La distribución hipergeométrica puede derivarse de un proceso experimental puro o de Bernouilli con las siguientes características:
#
#
#   1.  El proceso consta de n pruebas , separadas o separables de entre un conjunto de N pruebas posibles.
#   2.   Cada una de las pruebas puede dar únicamente dos resultados mutuamente excluyentes: A y no A.
#   3. En la primera prueba las probabilidades son :P(A)= p y P(A)= q ;con p+q=l.
#
#   La Distribución Hipergeométrica esta dada por la formula:
# ![image.png](data:image/png;base64,...)
#
#   Donde:
#   M = cantidad de éxitos posibles en
#   la población
#
#   N= tamaño de población
#
#   n= tamaño de la muestra
#
#   r= valor que toma la variable aleatoria

# %%
# Graficando Hipergeométrica
M, n, N = 30, 10, 12 # parametros de forma 
hipergeometrica = stats.hypergeom(M, n, N) # Distribución
x = np.arange(0, n+1)
fmp = hipergeometrica.pmf(x) # Función de Masa de Probabilidad
plt.plot(x, fmp, '--')
plt.vlines(x, 0, fmp, colors='b', lw=5, alpha=0.5)
plt.title('Distribución Hipergeométrica')
plt.ylabel('Probabilidad')
plt.xlabel('Valores')
plt.show()

# %%
# Histograma
aleatorios = hipergeometrica.rvs(1000)  # genera aleatorios

plt.hist(aleatorios, 20)
plt.ylabel('Frecuencia')
plt.xlabel('Valores')
plt.title('Distribución Hipergeométrica')
plt.show()

# %% [markdown]
# Ejemplo:
# Supongamos la extracción aleatoria de 8 elementos de un conjunto formado por 40 elementos totales (cartas baraja española) de los cuales 10 son del tipo A (salir oro) y 30 son del tipo complementario (no salir oro).
# Si realizamos las extracciones sin devolver los elementos extraídos y llamamos X al número de elementos del tipo A (oros obtenidos) que extraemos en las 8 cartas; X seguirá una distribución hipergeométrica de parámetros 40 , 8 , 10/40.H(40,8,0,25).
# Para calcular la probabilidad de obtener 4 oros:
#
# **P(X=4)=** ((10/4)*(30/4)/(40/8))
#
# **P(X=4)= 0.07**

# %% [markdown]
# _______________________________________

# %% [markdown]
#   * **Distribución Uniforme:** asigna probabilidades iguales a un conjunto finito de puntos del espacio. Modeliza fenómenos en los que tenemos un conjunto de n sucesos posibles, cada uno de los cuales con la misma probabilidad de ocurrir. Si aleatorizamos de forma que cada uno de éstos sucesos se corresponda con un número natural del 1 al n obtendremos una distribución uniforme.
#
#   La función para el comportamiento de una variable aleatoria discreta con distribución uniforme será:
#
#   ![image.png](data:image/png;base64,...)

# %%
a = 1
b = 10
x = np.arange(a, b + 1)
uniforme_discreta = stats.randint(a, b + 1)

uniforme_discreta_pmf = uniforme_discreta.pmf(x)


plt.plot(x, uniforme_discreta_pmf, 'bo', ms=8)
plt.plot(x, uniforme_discreta_pmf, '--', ms=8)
plt.vlines(x, 0, uniforme_discreta_pmf, colors='b', lw=5, alpha=0.5)
plt.xlabel('Valores')
plt.ylabel('Probabilidad')
plt.title('Distribución Uniforme Discreta')
plt.show()

# %%
# histograma
aleatorios = uniforme_discreta.rvs(1000)  # genera aleatorios
cuenta, cajas, ignorar = plt.hist(aleatorios, 20)
plt.ylabel('Frequencia')
plt.xlabel('Valores')
plt.title('Histograma Distribución Uniforme Discreta')
plt.show()

# %% [markdown]
# **Ejemplo:** El temario para un examen consta de 35 temas, de los cuales se elegirá uno al azar. Si un
# alumno no ha estudiado los 10 últimos temas ¿Cuál es la probabilidad de que el alumno
# sepa el tema elegido para el examen? Hallar la media y varianza
#
# **Solucion:** Sea X la variable aleatoria que representa el número de tema seleccionado para el examen,
# como todos los temas tienen la misma probabilidad de ser seleccionado, X sigue una
# distribución uniforme discreta de 35 elementos
#
# La probabilidad de salir el tema x es **P(X=x) = 1/35**
#
# El alumno aprueba el examen si le toca un tema del 1 al 25; así pues:
# La probabilidad de salir un tema estudiado es:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ________________________________________

# %% [markdown]
#   * **Distribución Binomial Negativa :** se utiliza en procesos que se requieran N casos favorables (primer éxito). Es decir, modela el número de ensayos necesarios para que se produzcan un número específico de eventos.
#
#   Condiciones:
#     * Cada secuencia es independiente de otras.
#     * En cada intento solamente son posibles dos resultados (éxito o fracaso)
#     * La probabilidad de éxito es constante en cada secuencia
#     * Los intentos continúan hasta que se consigan r éxitos
#
#   La funcion del comportamiento es la siguiente:
#
#   ![image.png](data:image/png;base64,...)
#
#   Donde:
#
#   x=  = número de ensayos hasta obtener el r-ésimo éxito
#
#  p = la probabilidad de pasar el control de calidad
#
#  r = la cantidad de éxitos

# %%
x = np.arange(3, 30)
r = 3
p = 0.1

binomial_negativa = stats.nbinom.pmf(x, r, p)

plt.plot(x, binomial_negativa, 'bo', ms=8)
plt.plot(x, binomial_negativa, '--', ms=8)
plt.vlines(x, 0, binomial_negativa, colors='b', lw=5, alpha=0.5)
plt.xlabel('Valores')
plt.ylabel('Probabilidad')
plt.title('Distribución Binomial Negativa')
plt.show()

# %%
# histograma
aleatorios = stats.nbinom.rvs(r, p, size=1000)  # genera aleatorios
cuenta, cajas, ignorar = plt.hist(aleatorios, 20)
plt.ylabel('Frequencia')
plt.xlabel('Valores')
plt.title('Distribución Binomial Negativa')
plt.show()

# %% [markdown]
# **Ejemplo:** Para tratar a un paciente de una afección de pulmón, han de ser operados en operaciones independientes sus 5 lóbulos pulmonares. La técnica a utilizar es tal que si todo va bien, lo que ocurre con probabilidad de 7/11, el lóbulo queda definitivamente sano, pero si no es así se deberá esperar el tiempo suficiente para intentarlo posteriormente de nuevo. Se practicará la cirugía hasta que 4 de sus 5 lóbulos funcionen correctamente. ¿Cuál es el valor de intervenciones que se espera que deba padecer el paciente? ¿Cuál es la probabilidad de que se necesiten 10 intervenciones?
#
# P(X=10) = (9/3) x (7/11)^4 x (4/11)^6
# **P(X=10) = 0.03185**
#
# u= 4 x 1/(7/11)
#
# **u= 6.28**

# %% [markdown]
# # **Referencias:**
#
#
# *   HIPERGEOMETRICA. (s. f.). s/n. Recuperado 30 de julio de 2022, de https://www.uv.es/ceaces/base/modelos%20de%20probabilidad/hipergeometrica.htm
#
# *   Suescun, N. A. R. (2018, 16 agosto). DISTRIBUCIONES DE PROBABILIDAD CON PYTHON. - Nathaly Andreina Rivera Suescun. Medium. https://medium.com/@24nars/distribuciones-de-probabilidad-con-python-70b952395c65
#
# * Briega, L. R. E. (2016, 29 junio). Distribuciones de probabilidad con Python. S/n. Recuperado 30 de julio de 2022, de https://relopezbriega.github.io/blog/2016/06/29/distribuciones-de-probabilidad-con-python/
